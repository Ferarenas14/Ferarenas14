# %% [markdown]
# # Gráfica de $f(x)=x - 3^{-x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-5, 5,100)

# %%
# Función cuadrática.
def f(x):
    return x - 3**(-x)
def g(x):
    return x
def h(x):
    return -3**(-x)

# %%
f(4)
# Out:
# 3.9876543209876543

# %%
# Graficar  funciones.
plt.figure(figsize=(10,10))
#Al restar la función g(x) a la función h(x) nos da como resultado f(x)
plt.plot(x, f(x))
plt.plot(x, g(x))
plt.plot(x, h(x))
plt.axhline(0, color="pink")
plt.axvline(0, color="pink")
plt.xlim(-10, 10)
plt.ylim(-10, 10)
#plt.savefig("output.png") # Guardar gráfico como imágen PNG.
# Mostrarlo.
plt.grid() #Color de malla
plt.title("Gráfica $f(x)=x-3^{-x}$") #Agregar titulo
plt.xlabel("Eje x") #Rotulos
plt.ylabel("Eje y") #Rotulos
plt.show()

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.
